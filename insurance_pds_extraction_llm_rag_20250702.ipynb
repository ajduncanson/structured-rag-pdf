# %% [markdown]
# # Retrieval-augmented generative AI pipeline
# ### to provide structured answeres to questions about documents
#
# specifically, Insurance product disclosure statements
#
# Author: AJ Duncanson, heavily borrowing from Thu Vu, see readme.

# %% [markdown]
# ## 0. Setting up

# %%
# !pip3 install --upgrade --quiet langchain langchain-community langchain-openai chromadb langchain_chroma
# !pip3 install --upgrade --quiet pypdf pandas streamlit python-dotenv
# Out:
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/aj.duncanson/.pyenv/versions/3.10.0/envs/env310/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/aj.duncanson/.pyenv/versions/3.10.0/envs/env310/bin/python -m pip install --upgrade pip' command.

# %%
# Import Langchain modules
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

#from langchain.vectorstores import Chroma
from langchain_chroma import Chroma


from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field

# Other modules and packages
import os
import tempfile
import streamlit as st  
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# %% [markdown]
# ### Define our LLM and our set of questions

# %%
llm = ChatOpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
# llm.invoke("Tell me a joke about cats")

# %% [markdown]
# Define PDS set

# %%
PDS_folder = "/Users/aj.duncanson/projects/structured-rag-pdf/pds/"
results_folder = "/Users/aj.duncanson/projects/structured-rag-pdf/results/"

# %%
# provider = "QBE"
# PDSs = [
#     "QM8505-1123 QBE Comprehensive Car Insurance PDS (web).pdf"
# ]

# %%
# provider = "Rollin"
# PDSs = [
#     "1747889291-rollin-car-insurance-pds-v4-29-apr-2025.pdf"
# ]

# %%
provider = "Youi"
PDSs = [
    "youi car-pds 20250702.pdf"
]
product_name = "Comprehensive Car Insurance"

# %%
# provider = "Budget Direct"
# PDSs = [
#     "Budget Direct car PDS A.pdf",
#     "Budget Direct Car Gold PDS B.pdf"
# ]
# product_name = "Comprehensive Gold Car Insurance"

# %% [markdown]
# Define question set

# %%
question_file = "car_insurance_questions.csv"
question_column = 'questions 20250702-06'

questions = pd.read_csv(PDS_folder+question_file)
data_points = questions["data_point"]
questions = questions[question_column]

questions = [q + ", ensuring that you only provide details relevant to the " + product_name + " product." for q in questions]

# %% [markdown]
# ## 1. Process PDF document

# %% [markdown]
# ### Load PDF document(s)

# %%
pages = []
for p in PDSs:
    loader = PyPDFLoader(PDS_folder + p)
    these_pages = loader.load()
    pages.extend(these_pages)

pages
# Out:
# [Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 0, 'page_label': '1'}, page_content='Car Insurance\nProduct Disclosure Statement - Part A\nCar Insurance Policy\nGeneral Terms and Conditions\nThis document prepared on 21 September 2023'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 1, 'page_label': '2'}, page_content='Product Issuer: Auto & General Insurance Company Limited\nABN 42 111 586 353\nAFS Licence No 285571\nRegistered Office: Level 13, 9 Sherwood Road, Toowong QLD 4066'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 2, 'page_label': '3'}, page_content="Summary of Cover\nCover Comprehensive\nThird Party\nProperty, Fire\nand Theft\nThird Party\nProperty Only\nAccidental damage to the car Yes No No\nFire Yes Yes No\nTheft Yes Yes No\nDamage to other people's property Yes Yes Yes\nPolicy Benefits and Options    Limits and conditions apply\nBenefits Comprehensive\nThird Party\nProperty, Fire\nand Theft\nThird Party\nProperty Only\nChoice of Market Value or Agreed\nValue*\nDamage to Other People's Property $20M $20M $20M\nEssential Repairs\nEmergency Transport and\nAccommodation\nHire Car Following a No Fault Accident\nHire Car Following Theft\nNew Car Replacement\nPersonal Effects (incl. Child Seats or\nCapsules)\nRepair Guarantee\nReplacement of Keys\nTowing Costs\nTrailer\nUninsured Motorist Damage N/A\n24/7 Claims\n* Eligibility criteria apply"),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page':
is PDS (and any applicable SPDS) becomes your Insurance Contract together with the\nmost recent Insurance Certificate.\nAfter reading the documents carefully, you should keep them in a safe place for future\nreference.\nOur Agreement\nIn return for meeting your obligations under this agreement, we will provide you the\nprotection described in this policy for events which occur during the period of insurance\nshown on your Insurance Certificate.\nHow We Send You Your Policy Documents\nOur preference is to send you your policy documents and communicate with you\nelectronically.\nWhen we send you your policy documents by email, they will be considered to have been\nreceived by you at the time it leaves our information system.\nIf you would like us to provide these documents by post, please let us know.\nIt is your responsibility to ensure that the email address and postal address you have\nprovided us with are both correct and up to date. If you need to confirm or change these\ndetails, please contact us.'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 7, 'page_label': '8'}, page_content='2\n Words With Special Meaning\nSome words when used in this PDS or the Insurance Certificate have special meaning.\nTerm Definition\nA a hire car that\nmeets your\nneeds\nA hire car that will reasonably fulfil your usual day to day mobility\nrequirements. It may not:\nl be the same make and/or model,\nl have the same motor and/or fuel type, and\nl offer the same features and/or prestige,\nas the insured car.\naccident or\nincident\nAn event that is sudden, unforeseen, unexpected and unintended\nby you.\nagreed value The amount we agree to insure the car for, during each term of\ninsurance. Your Insurance Certificate shows the amount (if\napplicable) and it may change each time you renew the policy.\nat fault claim Any claim which cannot be recovered from another party, either in\npart or in full, such as:\nl an accident where, given all available evidence, it is reasonable\nfor us to decide the driver of the car is partially or entirely at\nfault,\nl an accident where, given all available evidence, it is reasonable\nfor us to decide the driver of the other vehicle or another person\nis entirely at fault but you cannot tell us, or we cannot obtain,\ntheir full name, residential address and vehicle registration\nnumber,\nl theft, attempted theft or a malicious act,\nl storm, wind or hail,\nl fire, or\nl an accident involving an animal.\nC car The car, as specified on your Insurance Certificate, including the\nmanufacturer©s standard accessories forming part of the car and\nany other accessories or modifications that we have agreed to\ncover.'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 8, 'page_label': '9'}, page_content='3PRODUCT DISCLOSURE STATEMENT - PART A\nTerm Definition\ncommunicable\ndisease\nAny disease which can be transmitted from organism to organism\nvia any substance or agent (for example, a virus or bacterium)\nwhere the disease, substance or agent can:\nl cause or threaten damage to human health or human welfare,\nor\nl cause or threaten damage to, deterioration of, loss of value of,\nmarketability of or loss of use of property.\ncomputer\nsystem\nAny computer, hardware, software, communications system,\nelectronic device, server, cloud or microcontroller that forms part\nof or is associated with the car, and any associated input, output,\ndata storage device, networking equipment or backup facility.\nD data Information, facts, concepts, code or any other information of any\nkind that is recorded or transmitted in a form to be used, accessed,\nprocessed, transmitted or stored by a computer system.\ndriver Any person operating, using, or in charge of the car.\nH household\nmember\nA person who normally resides with the regular driver.\nM market value The value of the car at the time of the loss or damage, taking into\naccount factors such as the make, model, age, kilometres travelled\nand overall condition. We may use local market prices, recognised\nindustry publications or other sources to determine the market\nvalue.\nIt does not include any allowance for:\nl registration,\nl compulsory third party insurance,\nl stamp duty,\nl registration transfer fees,\nl dealer charges and delivery, or\nl dealer or extended warranty.\nmodification Any alteration to the car©s standard engine, exhaust system, body,\ninterior, suspension, wheels or paintwork that changes the\nfunctionality, performance, security or value of the car from the\nmanufacturer©s original design.\nN no fault\naccident\nAn accident where, given all available evidence, it is reasonable for\nus to decide the driver of another vehicle, or another person, is\nentirely at fault, and you tell us, or we can obtain, their full name,\nresidential address and vehicle registration number.'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page':
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 34, 'page_label': '35'}, page_content='29PRODUCT DISCLOSURE STATEMENT - PART A\nWhat Happens if You Have a Problem With\nOur Service\nWe want to resolve any complaint or dispute you have as quickly as possible. The following\nsteps are part of our complaint and dispute resolution process.\nStep 1 - Contact us\nThe best place to start is to contact our Customer Service Team\nVisit budgetdirect.com.au/dispute-resolution\nEmail customercare@autogeneral.com.au\nCall 1300\xa0139\xa0591 for claims\n1300\xa0306\xa0560 for anything else\nStep 2 - Resolve\nOur teams will try to resolve your complaint or dispute immediately and will provide you\nwith a reference number.\nStep 3 - Escalate\nIf we are unable to resolve your complaint or dispute to your satisfaction, we will escalate it\nto our Customer Disputes Resolution team for review.\nOur Customer Disputes Resolution team will work together with you to try to resolve your\ncomplaint.\nAustralian Financial Complaints Authority\nOur aim is to resolve complaints within 30 days. If we are unable to finalise your complaint\nwithin this time, we will let you know the reason for the delay and provide the contact\ndetails for the external dispute resolution scheme run by the Australian Financial Complaints\nAuthority (AFCA).\nIf you are dissatisfied with our final decision you can also contact AFCA directly.\nCall 1800 931 678 (free call)\nEmail info@afca.org.au\nMail GPO Box 3, Melbourne VIC 3001\nAFCA independently resolves disputes between financial service providers (like insurers) and\ntheir clients.'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 35, 'page_label': '36'}, page_content='30 Financial Claims Scheme\nThe Financial Claims Scheme (FCS) provides protection to certain claimants who make valid\nclaims under ©protected policies© in a situation where the insurer is insolvent.\nA person entitled to claim under this policy may be entitled to payment under the FCS in the\nunlikely event that we become insolvent. However, access to the FCS is subject to eligibility\ncriteria.\nYou can obtain information about the FCS from the APRA website at apra.gov.au and the\nAPRA hotline on 1300 55 88 49.\nContact Details\nYou may contact us by writing to:\nAuto & General Insurance Company Limited\nPO Box 342, Toowong QLD 4066'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 36, 'page_label': '37'}, page_content='Page intentionally left blank'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 37, 'page_label': '38'}, page_content='Page intentionally left blank'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 38, 'page_label': '39'}, page_content='Page intentionally left blank'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-10T03:22:15+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct car PDS A.pdf', 'total_pages': 40, 'page': 39, 'page_label': '40'}, page_content='Contact details\n1300\xa0139\xa0591 for claims\n1300\xa0306\xa0560 for anything else\nbudgetdirect.com.au'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='Product Disclosure Statement - Part B\nGold Car\nInsurance\nPolicy\nThis document prepared on 21 September 2023'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 1, 'page_label': '2'}, page_content='What is a Product Disclosure Statement?\nThis Product Disclosure Statement (PDS) will assist you to make an informed decision\nabout our insurance product. It consists of the following parts, which you should read\nbefore making a final decision to purchase:\n1) PART A contains the general terms and conditions of all our policies.\n2) PART B supplements Part A and contains specific details about the product option(s) that\napply. The product option that applies to you will be shown on your quote and your\nInsurance Certificate.\n3) Supplementary Product Disclosure Statements (SPDS), if applicable, contain changes to\nPart A and Part B.\nIf You Have Already Purchased Our Policy\nThis PDS (and any applicable SPDS) becomes your Insurance Contract together with the\nmost recent Insurance Certificate.\nAfter reading the documents carefully, you should keep them in a safe place for future\nreference.\nProduct Issuer: Auto & General Insurance Company Limited\nABN 42 111 586 353\nAFS Licence No 285571\nRegistered Office: Level 13, 9 Sherwood Road, Toowong QLD 4066'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 2, 'page_label': '3'}, page_
ance Certificate.\nIf we accept your at fault claim, we will arrange and pay the daily cost for a hire car that\nmeets your needs. You must not arrange your own hire car without first obtaining our\napproval. If you do, then we may not cover the full hire car costs, and only reimburse you\nthe amount we would have authorised had you spoken to us first.\nIf we are unable to arrange a hire car for you, we will reimburse you what it would cost you\nto fulfil your usual day to day mobility requirements, up to a maximum of $75 per day.\nWe will pay for this benefit until the first of the following occur:\nl the car is repaired,\nl your claim is paid, or\nl 14 days of hire have been used.\nWhere the car is safe to drive, the hire car will only be available from the date:\nl the authorised repairs are due to start, or\nl we assess the car to be a total loss.\nWe will not pay any additional costs of hiring, including but not limited to fuel, insurance or\ndamage to the hire car. You need to agree to the hire car company hiring conditions\n(including paying a rental bond, insurance and any excess if you damage the hire car) and\ncollect and return the hire car.\nNote: Hire Car Following a No Fault Accident and Hire Car Following Theft are standard\npolicy benefits (refer to PDS Part A).\nChoice of Repairer (optional)\nThis optional benefit is only available with ©Comprehensive© cover and applies only if\nshown as included on your Insurance Certificate.\nIf you have purchased this option, you may choose to nominate your preferred repairer,\nwhich may be a repairer from our repair network.\nSee ©If you have the Choice of Repairer optional cover© in PDS Part A for how this affects\nyour claim.'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 5, 'page_label': '6'}, page_content='4\n Fees That May Be Charged\nOnce you have taken out a policy, our agent, as shown on your Insurance Certificate, may\ncharge any of the fees below (if applicable):\nEarly Cancellation $40.00\nMonthly Instalment Processing 12 payments of 66 cents per $100 of\npremium or part thereof\nFortnightly Instalment Processing 26 payments of 31 cents per $100 of\npremium or part thereof'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 6, 'page_label': '7'}, page_content='Page intentionally left blank'),
#  Document(metadata={'producer': '', 'creator': 'Quadient~Inspire Designer~16.0.635.4', 'creationdate': '2025-02-18T06:09:25+00:00', 'source': '/Users/aj.duncanson/projects/structured-rag-pdf/pds/Budget Direct Car Gold PDS B.pdf', 'total_pages': 8, 'page': 7, 'page_label': '8'}, page_content='Contact details\n1300\xa0139\xa0591 for claims\n1300\xa0306\xa0560 for anything else\nbudgetdirect.com.au')]

# %% [markdown]
# ### Split document

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500,
                                            chunk_overlap=200,
                                            length_function=len,
                                            separators=["\n\n", "\n", " "])
chunks = text_splitter.split_documents(pages)

# %% [markdown]
# ### Create embeddings

# %%
def get_embedding_function():
    embeddings = OpenAIEmbeddings(
        model="text-embedding-ada-002", openai_api_key=OPENAI_API_KEY
    )
    return embeddings

embedding_function = get_embedding_function()
test_vector = embedding_function.embed_query("cat")

# %%
# from langchain.evaluation import load_evaluator

# evaluator = load_evaluator(evaluator="embedding_distance", 
#                             embeddings=embedding_function)

# evaluator.evaluate_strings(prediction="Amsterdam", reference="coffeeshop")

# %%
# evaluator.evaluate_strings(prediction="Paris", reference="coffeeshop")

# %% [markdown]
# ### Create vector database

# %%
import uuid

def create_vectorstore(chunks, embedding_function
                       #, vectorstore_path
                       ):

    # Create a list of unique ids for each document based on the content
    ids = [str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.page_content)) for doc in chunks]
    
    # Ensure that only unique docs with unique ids are kept
    unique_ids = set()
    unique_chunks = []
    
    unique_chunks = [] 
    for chunk, id in zip(chunks, ids):     
        if id not in unique_ids:       
            unique_ids.add(id)
            unique_chunks.append(chunk) 

    # Create a new Chroma database from the documents
    vectorstore = Chroma.from_documents(documents=unique_chunks, 
                                        ids=list(unique_ids),
                                        embedding=embedding_function, 
                                        #persist_directory = vectorstore_path
                                        )
    
    return vectorstore

# %%
# ids = [str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.page_content)) for doc in chunks]

# # Ensure that only unique docs with unique ids are kept
# unique_ids = set()
# unique_chunks = []

# unique_chunks = [] 
# for chunk, id in zip(chunks, ids):     
#     if id not in unique_ids:       
#         unique_ids.add(id)
#         unique_chunks.append(chunk)

# %%
# unique_chunks

# %%
# Create vectorstore
vectorstore = create_vectorstore(chunks=chunks, 
                                 embedding_function=embedding_function, 
                                 #vectorstore_path="vectorstore_chroma"
                                 )

# %% [markdown]
# ## 2. Query for relevant data

# %%
# Load vectorstore
#vectorstore = Chroma(persist_directory="vectorstore_chroma", embedding_function=embedding_function)

# %%
# Create retriever 
retriever = vectorstore.as_retriever(search_type="similarity")

# relevant_chunks = retriever.invoke("Who underwrites this policy")
# relevant_chunks

# %%
# Prompt template
PROMPT_TEMPLATE = """
You are an assistant for question-answering tasks. 
Your task is to answer the question about specific details of the insurance policy described in the retrieved context.
Use the following pieces of retrieved context to answer
the question. If you don't know the answer, say that you
don't know. DON'T MAKE UP ANYTHING.

{context}

---

Answer the question based on the above context: {question}
"""

# %%
PROMPT_TEMPLATE
# Out:
# "\nYou are an assistant for question-answering tasks. \nYour task is to answer the question about specific details of the insurance policy described in the retrieved context.\nUse the following pieces of retrieved context to answer\nthe question. If you don't know the answer, say that you\ndon't know. DON'T MAKE UP ANYTHING.\n\n{context}\n\n---\n\nAnswer the question based on the above context: {question}\n"

# %% [markdown]
# ## 3. Generate responses

# %%
# Concatenate context text
context_text = "\n\n---\n\n".join([doc.page_content for doc in relevant_chunks])

# Create prompt
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)

# %%
# prompt = prompt_template.format(context=context_text, 
#                                 question="Who underwrites this policy?")
# print(prompt)

# %%
# llm.invoke(prompt)

# %% [markdown]
# ### Using Langchain Expression Language

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
# rag_chain = (
#             {"context": retriever | format_docs, "question": RunnablePassthrough()}
#             | prompt_template
#             | llm
#         )
# rag_chain.invoke("What's the name of the insurance product?")

# %%
# rag_chain.invoke("What is the cover limit in case of rental car after an accident?")

# %%
# rag_chain.invoke("Is cover is provided for baby capsules, and is there a dollar limit")

# %%
# rag_chain.invoke("What is the maximum amount of cover for legal liability?")

# %% [markdown]
# ## 4. Generate structured responses

# %% [markdown]
# ### Still exploring the structure that's most useful for our needs, and also using very early draft prompts.

# %%
# class AnswerWithSources(BaseModel):
#     """An answer to the question, with sources and reasoning."""
#     answer: str = Field(description="Answer to question")
#     sources: str = Field(description="Full direct text chunk from the context used to answer the question")
#     reasoning: str = Field(description="Explain the reasoning of the answer based on the sources")

# class ExtractedInfoWithReasoning(BaseModel):
#     """Extracted information about the cover item"""
#     summary_details: AnswerWithSources
#     dollar_limit: AnswerWithSources
#     conditions: AnswerWithSources
#     exclusions: AnswerWithSources

# class JustInfo(BaseModel):
#     """Extracted information about the cover item"""
#     summary: str = Field(description="Answer to question")
#     dollar_limit: str = Field(description="Answer to question")
#     conditions: str = Field(description="Answer to question")
#     exclusions: str = Field(description="Answer to question")

class ExtractedInfo(BaseModel):
    """Extracted information about the cover item"""
    this_item_of_cover_is_included_as_standard: bool = Field("Cover is included as standard, not optional")
    this_item_of_cover_is_optional: bool = Field("Cover is optional, not included as standard")
    this_item_is_not_covered_at_all: bool = Field("This cover is not provided at all")

    #is_this_part_of_the_standard_cover_or_an_optional_cover_or_not_covered:  str = Field(description="Standard Cover or Optional Cover or Not Covered")
    summary: str = Field(description="Summary of answer to question, including all relevant numerical limits")
    #summary_2: str = Field(description="A concise summary of the cover provided")
    list_of_numerical_limits_related_to_this_item_of_cover: str = Field("List the numerical limits that apply to this specific item of cover including dollar limits, limits on the number of days the benefit can be paid, and limits to the number of years or number of kilometers used in determining whether this cover applies") 
    #numerical_limits_to_the_dollars_or_distance_or_timeframe_2: str = Field("Answer to question") 
    #dollar_limit: str = Field(description="Answer to question")
    #other_limits_to_cover: str = Field(description="What other limits apply to the cover, other than dollar amounts?")
    #other_limits_to_cover_2: str = Field(description="What distance, time period or other limits apply to the cover, other than dollar amounts?")
    conditions: str = Field(description="Answer to question")
    exclusions: str = Field(description="Answer to question")
    sources: str = Field(description="Full direct text chunk from the context used to answer the question")
    reasoning: str = Field(description="Explain the reasoning of the answer based on the sources")

# %%
rag_chain = (
            {"context": retriever | format_docs, "question": RunnablePassthrough()}
            | prompt_template
            | llm.with_structured_output(ExtractedInfo, strict=True)
        )

# %%
# rag_chain.invoke("Give me a summary, dollar limit, specific conditions and specific exclusions relating to personal items cover.")

# %% [markdown]
# ### Get structured responses and compile into a result format

# %%
# Get the structured responses for each question in the array

structured_responses = [rag_chain.invoke(q).model_dump() for q in questions]

# %%
structured_responses[0]
# Out:
# {'this_item_of_cover_is_included_as_standard': True,
#  'this_item_of_cover_is_optional': False,
#  'this_item_is_not_covered_at_all': False,
#  'summary': 'Comprehensive Gold Car Insurance includes cover for personal effects, which encompasses items like child seats or capsules. There is a specific limit of $1,000 for stolen keys and locks, but there is no explicit limit mentioned for personal items.',
#  'list_of_numerical_limits_related_to_this_item_of_cover': 'Up to $1,000 for stolen keys and locks; no specific dollar limit for personal effects mentioned.',
#  'conditions': 'Personal effects coverage is included in the Comprehensive policy, subject to limits noted in the policy document.',
#  'exclusions': "General exclusions apply, including loss of value or depreciation of personal items, loss of use or other financial loss arising from an incident, and costs that occur due to the mechanical or electronic breakdown of associated items, unless they are guaranteed under the insurer's Quality Guarantee.",
#  'sources': 'Summary of Cover, Policy Benefits and Options, General exclusions.',
#  'reasoning': 'The extracted information has been gathered based on the product disclosure statement which outlines the coverage limits and exclusions related to personal effects within the Comprehensive Gold Car Insurance policy.'}

# %%
# Store in a df 

df = pd.DataFrame(structured_responses)

df.insert(0, "provider", provider)
df.insert(1, "PDS", ", ".join(PDSs))
df.insert(2, "data_point", data_points)
df.insert(3, "question", questions)
df
# Out:
#          provider                                                PDS  \
# 0   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 1   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 2   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 3   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 4   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 5   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 6   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 7   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 8   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 9   Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 10  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 11  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 12  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 13  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 14  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 15  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 16  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 17  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 18  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 19  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 20  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 21  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 22  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 23  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 24  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
# 25  Budget Direct  Budget Direct car PDS A.pdf, Budget Direct Car...
#
#                                            data_point  \
# 0                                      personal items
# 1                                  choice of repairer
# 2                                        agreed value
# 3                                        market value
# 4                        agreed value or market value
# 5                              new car if written off
# 6                                    windscreen cover
# 7                emergency repairs without assessment
# 8                             emergency accommodation
# 9                           emergency accommodation 2
# 10                                   emergency towing
# 11                                      genuine parts
# 12                             rental car after theft
# 13    rental car after accident that was not my fault
# 14  rental car after an accident that I caused or ...
# 15                                   replacement keys
# 16                              baby capsule or seats
# 17                                      modifications
# 18                         accidental death of driver
# 19                                    rideshare cover
# 20                                    legal liability
# 21                                 trailer or caravan
# 22                               trailer or caravan 2
# 23                                young driver excess
# 24                                           PDS date
# 25                                        underwriter
#
#                                              question  \
# 0   Give me a summary, dollar limit, any other lim...
# 1   Can I choose my own repairer?only provide deta...
# 2   Can I have my vehicle insured for an agreed va...
# 3   Can I have my vehicle insured for the market v...
# 4   If the car is a total loss, does this insuranc...
# 5   Will a new replacement car be provided if my c...
# 6   Give me the excess that applies to windscreen ...
# 7   Give me a summary, dollar limit, any other lim...
# 8   Give me a summary, dollar limit, any distance ...
# 9   Regarding insurance cover for emergency accomm...
# 10  Give me a summary, dollar limit, any distance ...
# 11  If the policy covers the use of genuine parts ...
# 12  Regarding insurance cover of a hire car after ...
# 13  Regarding insurance cover for the cost of a hi...
# 14  Does the insurance provide a hire car after an...
# 15  Regarding insurance cover for the cost of repl...
# 16  Give me a summary, cover limit, specific condi...
# 17  If this insurance policy is paying for repairs...
# 18  Is there a benefit paid on death of the driver...
# 19  Regarding insurance cover while my car is bein...
# 20  What is the cover limit for legal liability cl...
# 21  Give me a summary, cover limit, specific condi...
# 22  Regarding insurance cover for a trailer or car...
# 23  Is there an additional excess payable for youn...
# 24  What is the issue date of this PDS?only provid...
# 25  Which insurance company underwites this insura...
#
#     this_item_of_cover_is_included_as_standard  \
# 0                                         True
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                         True
# 5                                         True
# 6                                        False
# 7                                         True
# 8                                         True
# 9                                         True
# 10                                        True
# 11                                        True
# 12                                        True
# 13                                        True
# 14                                       False
# 15                                       False
# 16                                        True
# 17                                       False
# 18                                        True
# 19                                       False
# 20                                        True
# 21                                       False
# 22                                       False
# 23                                       False
# 24                                       False
# 25                                       False
#
#     this_item_of_cover_is_optional  this_item_is_not_covered_at_all  \
# 0                            False                            False
# 1                             True                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
# 5                            False                            False
# 6                             True                            False
# 7                            False                            False
# 8                            False                            False
# 9                            False                            False
# 10                           False                            False
# 11                           False                            False
# 12                           False                            False
# 13                           False                            False
# 14                            True                            False
# 15                           False                            False
# 16                           False                            False
# 17                            True                            False
# 18                           False                            False
# 19                           False                             True
# 20                           False                            False
# 21                            True                            False
# 22                            True                            False
# 23                           False                            False
# 24                           False                            False
# 25                            True                            False
#
#                                               summary  \
# 0   Comprehensive Gold Car Insurance includes cove...
# 1   With Comprehensive Gold Car Insurance, you can...
# 2   You can have your vehicle insured for an agree...
# 3   Yes, under the Comprehensive Gold Car Insuranc...
# 4   If the car is a total loss under Comprehensive...
# 5   If your car is written off and you purchased i...
# 6   The basic excess applies to windscreen claims ...
# 7   Emergency travel & accommodation cover provide...
# 8   Emergency accommodation and transport cover is...
# 9   Emergency accommodation and transport is cover...
# 10  Under Comprehensive Gold Car Insurance, emerge...
# 11  The policy covers the use of genuine new mecha...
# 12  If you make a claim for the theft of your car,...
# 13  In the event of an accident where you are not ...
# 14  The insurance provides a hire car after an acc...
# 15  If car keys are stolen, the cost of replacing ...
# 16  Comprehensive cover includes coverage for chil...
# 17  The insurance policy will cover aftermarket ac...
# 18  A Death Benefit is paid if the driver of your ...
# 19  Insurance cover does not include any use of th...
# 20  The legal liability cover limit for Comprehens...
# 21  The Comprehensive Gold Car Insurance includes ...
# 22  Trailer cover is optional under Comprehensive ...
# 23  Yes, an additional excess is payable for young...
# 24  The issue date of the Product Disclosure State...
# 25  The comprehensive cover provides extensive pro...
#
#    list_of_numerical_limits_related_to_this_item_of_cover  \
# 0   Up to $1,000 for stolen keys and locks; no spe...
# 1
# 2
# 3   The maximum payout for a claim on a replacemen...
# 4
# 5   Limit of 90 days for sourcing a replacement ca...
# 6   The specific amount of the excess and the redu...
# 7    Up to $500 for emergency travel & accommodation.
# 8   Up to $500 for emergency travel & accommodatio...
# 9   No specific numerical limit provided for emerg...
# 10  Covered up to the reasonable cost for one tow ...
# 11
# 12  Maximum hire car benefit is limited to 14 days...
# 13
# 14  None specified in the context regarding numeri...
# 15  The most we will pay for each claim is $1,000 ...
# 16  Details regarding specific amounts, events, an...
# 17  Amounts for aftermarket accessories and modifi...
# 18                                             $5,000
# 19
# 20                                        $20,000,000
# 21  $1,000 per item; maximum claim amount noted on...
# 22                                                N/A
# 23  There is no specific numerical limit provided ...
# 24
# 25  Up to $75 per day for reimbursement of mobilit...
#
#                                            conditions  \
# 0   Personal effects coverage is included in the C...
# 1   You must provide a quotation from your preferr...
# 2   Eligibility criteria apply for selecting an in...
# 3   You need to specify an amount for after market...
# 4   The agreed value includes the value of any acc...
# 5   The new replacement car benefit applies if you...
# 6   The reduced window glass excess is only availa...
# 7   The emergency travel & accommodation cover is ...
# 8   You should arrange and pay for the emergency a...
# 9   The emergency accommodation and transport cove...
# 10  Coverage applies if you're covered under secti...
# 11  Genuine new mechanical parts are used where av...
# 12  A hire car will only be provided if arranged t...
# 13  A hire car will only be provided if arranged t...
# 14  The hire car will only be provided where arran...
# 15  This cover only applies if you have Comprehens...
# 16  Specific conditions regarding the coverage for...
# 17  You need to specify the amount for aftermarket...
# 18  The death must result from an injury caused in...
# 19  The use of the car for rideshare services is s...
# 20  Covers the driver's legal liability for third ...
# 21  The optional cover is only available if you ha...
# 22  This cover is available under optional cover f...
# 23  The additional excess applies to claims where ...
# 24
# 25  Optional benefits such as Accident Hire Car ar...
#
#                                            exclusions  \
# 0   General exclusions apply, including loss of va...
# 1   If 'Choice of Repairer' is not included in you...
# 2
# 3   Disability modifications and campervan/motorho...
# 4                                                 N/A
# 5   The benefit does not apply if the car had any ...
# 6   Exclusions are not specified in the provided c...
# 7   General exclusions apply; for example, loss of...
# 8   Specific exclusions apply as per section 4; ge...
# 9   No exclusions were explicitly listed for the e...
# 10  Storage costs incurred before lodging a claim ...
# 11  None specified regarding the use of genuine pa...
# 12  Additional costs associated with the hire car ...
# 13  Not covered are: loss or damage to the hire ca...
# 14  The running costs of the hire car (fuel, tolls...
# 15  The exclusion details are not specified direct...
# 16  There are no specific exclusions mentioned for...
# 17  The policy does not automatically cover afterm...
# 18  N/A based on the provided context, but typical...
# 19  Carrying passengers for payment, including rid...
# 20  Excludes damage to the car or substitute car a...
# 21  Contents theft or attempted theft is not cover...
# 22  Loss, damage, or theft of business items from ...
# 23  The additional excess does not apply if the ca...
# 24
# 25  Certain conditions apply, such as needing prio...
#
#                                               sources  \
# 0   Summary of Cover, Policy Benefits and Options,...
# 1   Choice of Repairer (optional) This optional be...
# 2   If you have an agreed value policy, you should...
# 3   The replacement car will be covered for the sa...
# 4   If the car is a total loss, we will: pay you t...
# 5   New Car Replacement ± If you purchased the car...
# 6   3PRODUCT DISCLOSURE STATEMENT - PART B: Reduce...
# 7   Emergency travel & accommodation\nUp to $500 i...
# 8   Emergency Accommodation, Transport and Repairs...
# 9   Emergency Accommodation, Transport and Repairs...
# 10  2. Towing Costs\nThis only applies if you have...
# 11  If the car is less than 3 years old, we use ne...
# 12  If we accept your claim for the theft of the c...
# 13  The hire car benefit will cease from the time ...
# 14  The insurance provides a hire car after an acc...
# 15  This only applies if you have Comprehensive or...
# 16  Your Insurance Certificate shows which of thes...
# 17  If you have an agreed value policy, you should...
# 18  We will pay $5,000 to your legal representativ...
# 19  A car that is used to carry paying passengers ...
# 20  The most we will pay for each claim is $20,000...
# 21  The most we will pay for each item is the less...
# 22  The most we will pay for each item is the less...
# 23  For example, this could include unlisted drive...
# 24  Product Disclosure Statement - Part B - Gold C...
# 25  Comprehensive cover includes liability for dam...
#
#                                             reasoning
# 0   The extracted information has been gathered ba...
# 1   The context clearly states that the ability to...
# 2   The provided context specifies that for those ...
# 3   The question specifically asked about the Comp...
# 4   The context specifies that for a total loss un...
# 5   This answer is based on the section that outli...
# 6   The information specifies that there is a basi...
# 7   The summary clearly indicates the limit placed...
# 8   The context clearly outlines the coverage for ...
# 9   The question specifically asks about the detai...
# 10  The answer is based on the comprehensive cover...
# 11  The context states that genuine new mechanical...
# 12  The information regarding the hire car benefit...
# 13  The relevant sections from the context indicat...
# 14  The analysis of the retrieved context indicate...
# 15  This summary is derived directly from the prov...
# 16  The provided text mentions that Comprehensive ...
# 17  The context specifies that aftermarket accesso...
# 18  The context explicitly states that a death ben...
# 19  The context clearly states that using a car fo...
# 20  The context clearly states the maximum payment...
# 21  Based on the provided policy details, the opti...
# 22  The context indicates that cover for trailers ...
# 23  The context specifies that additional excesses...
# 24  The answer is based directly on the informatio...
# 25  The information specifies that comprehensive c...

# %%
# save to csv file

timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")

df.to_csv(results_folder+"pds_output_"+provider+"_"+timestamp+".csv", index=False)
